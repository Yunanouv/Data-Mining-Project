# %% [markdown]
# The goal of this task is to explore the Yelp data set to get a sense about what the data look like and their characteristics. You can think about the goal as being to answer questions such as:
#
# What are the major topics in the reviews? Are they different in the positive and negative reviews? Are they different for different cuisines? What does the distribution of the number of reviews over other variables (e.g., cuisine, location) look like? What does the distribution of ratings look like? In general, you can address such questions by showing visualization of statistics computed based on the data set or topics extracted from review text.
#
# You must complete the following specific tasks.
#
# Task 1.1:
#
# Use a topic model (e.g., PLSA or LDA) to extract topics from all the review text (or a large sample of them) and visualize the topics to understand what people have talked about in these reviews. For example, after applying LDA to a sample of the reviews, we obtained the following visualization. Here the opacity of each node corresponds to its weight in each topic.
#
# Task 1.2:
#
# Do the same for two subsets of reviews that are interesting to compare (e.g., positive vs. negative reviews for a particular cuisine or restaurant), and visually compare the topics extracted from the two subsets to help understand the similarity and differences between these topics extracted from the two subsets. You can form these two subsets in any way that you think is interesting. Here we show a sample visualization for a sample of reviews with high and low ratings.

# %%
import json
import os
import pandas as pd
import glob
import plotly.graph_objects as go
import nltk
from plotly.graph_objects import Scatter, Layout, Marker, Line
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
# already executed
# def sample_json_data(file_pattern, sample_size=100):
#     """Reads JSON files and returns a sample of the data."""
#     all_files = glob.glob(file_pattern)
#     sample_data = []
#     for file in all_files:
#         with open(file, 'r') as f:
#             for line in f:
#                 try:
#                     json_data = json.loads(line.strip())
#                     sample_data.append(json_data)
#                     if len(sample_data) >= sample_size:
#                         return pd.DataFrame(sample_data)
#                 except json.JSONDecodeError as e:
#                     print(f"Error decoding JSON: {e}")
#     return pd.DataFrame(sample_data)

# df_sample = sample_json_data(r'D:\LEARNING AND COURSES\COURSERA\Data Mining Specialization\6. Data Mining Project\yelp_dataset_challenge_academic_dataset\dataset\yelp_academic_dataset_review.json', sample_size=500)
# df_sample.to_json('sample_data.json', orient='records', lines=True)

# %%
# Download NLTK data files
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Mount Google Drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Check Duplicates

# %%
# Function to check for duplicates in a multi-line JSON file
def check_duplicates_in_multiline_json(file_path, key=None):
    try:
        # Store each JSON object in a list
        data = []
        duplicates = []
        seen = set()

        # Read the file line-by-line
        with open(file_path, 'r') as file:
            for line in file:
                try:
                    item = json.loads(line.strip())  # Parse each line as a JSON object
                    if key:
                        # Check for duplicates based on a specific key
                        if item.get(key) in seen:
                            duplicates.append(item)
                        else:
                            seen.add(item.get(key))
                    else:
                        # Check for exact duplicate records
                        item_tuple = tuple(sorted(item.items())) if isinstance(item, dict) else tuple(item)
                        if item_tuple in seen:
                            duplicates.append(item)
                        else:
                            seen.add(item_tuple)

                    data.append(item)  # Add each parsed item to the data list
                except json.JSONDecodeError as e:
                    print(f"Error parsing line: {line}")
                    print(f"JSONDecodeError: {e}")

        # Output duplicates if found
        if duplicates:
            print(f"Found {len(duplicates)} duplicates in the JSON file.")
            for i, duplicate in enumerate(duplicates, 1):
                print(f"Duplicate {i}: {duplicate}")
        else:
            print("No duplicates found.")

    except Exception as e:
        print(f"Error processing file: {e}")

# File path to your multi-line JSON file
file_path = '/content/drive/MyDrive/Data Mining Project UIUC/dataset/yelp_academic_dataset_business.json'

# Check for duplicates in the multi-line JSON file
# If you want to check for duplicates based on a specific key, pass the key as a second argument (e.g., 'business_id')
check_duplicates_in_multiline_json(file_path, key='business_id')
# Out:
# No duplicates found.

# %% [markdown]
# Topics Extraction and Visualization
#
# Get 10 topics from 100 samples data using LDA. Then, visualize the topics using radia dendrogram from D3.js library and clusters bubble chart.

# %%
def read_json_files(file):
    """Reads a JSON file and returns a DataFrame."""
    data = []
    with open(file, 'r') as f:
        for line in f:
            try:
                json_data = json.loads(line.strip())
                data.append(json_data)
            except json.JSONDecodeError as e:
                print(f"Error decoding JSON: {e}")
    return pd.DataFrame(data)

def preprocess_text(text):
    """Preprocess the review text."""
    stop_words = set(stopwords.words('english'))
    tokens = word_tokenize(text.lower())
    return ' '.join([word for word in tokens if word.isalnum() and word not in stop_words])

def readdata(file, topic_count):
    """Reads data from JSON files and performs LDA topic modeling."""
    df = read_json_files(file)
    df['processed_text'] = df['text'].apply(preprocess_text)

    vectorizer = CountVectorizer()
    X = vectorizer.fit_transform(df['processed_text'])

    lda = LatentDirichletAllocation(n_components=topic_count, random_state=0)
    topic_distribution = lda.fit_transform(X)  # Getting topic distribution for each document

    # Calculate topic frequencies
    topic_frequencies = topic_distribution.sum(axis=0)

    # Get topics and words
    feature_names = vectorizer.get_feature_names_out()
    topics = {}
    for topic_idx, topic in enumerate(lda.components_):
        top_features_ind = topic.argsort()[-10:]  # Adjust number of words per topic
        top_features = [feature_names[i] for i in top_features_ind]
        topics[topic_idx] = top_features

    return topics, topic_frequencies

def export_topics_to_json(topics, file_name='topics.json'):
    """Exports topics dictionary to a JSON file."""
    with open(file_name, 'w') as f:
        json.dump(topics, f)

# %%
def build_text(key, values):
    result = 'Topic ' + str(key) + ': '
    for value in values:
        result += (value + ' ')
    return [result]

def build_trace(dataset, topic_frequencies):
    traces = []
    max_frequency = max(topic_frequencies)  # To scale sizes

    for key, frequency in enumerate(topic_frequencies):
        trace = go.Scatter(
            x=[key + 1],  # Topic ID starts from 1
            y=[frequency],  # Group Frequency based on calculated values
            text=build_text(key, dataset[key]),
            mode='markers',
            name='Topic ' + str(key + 1),
            marker=go.scatter.Marker(
                sizemode='diameter',
                sizeref=2. * max_frequency / (30. ** 2),  # Adjust size scaling
                size=[30. * (frequency / max_frequency)],  # Scale size by frequency
                opacity=frequency / max_frequency,  # Adjust opacity
                line=go.scatter.marker.Line(width=2),
            )
        )
        traces.append(trace)
    return traces

def build_layout():
    layout = Layout(
        title='Cluster of Topics by LDA',
        showlegend=False,
        height=600,
        width=800,
        xaxis=dict(
            title='Topic ID',
            gridcolor='rgb(255, 255, 255)',
            zerolinewidth=1,
            ticklen=5,
            gridwidth=1,
        ),
        yaxis=dict(
            title='Group Frequency (1000x)',
            gridcolor='rgb(255, 255, 255)',
            zerolinewidth=1,
            ticklen=5,
            gridwidth=2,
        ),
        paper_bgcolor='rgb(243, 243, 243)',
        plot_bgcolor='rgb(243, 243, 243)',
    )
    return layout

# %%
# Main function to use topic frequencies
def main(file):
    dataset, topic_frequencies = readdata(file, 10)  # Get topics and their frequencies
    export_topics_to_json(dataset)  # Export topics to JSON file
    print("Topics successfully exported to topics.json")
    traces = build_trace(dataset, topic_frequencies)
    layout = build_layout()
    fig = go.Figure(data=traces, layout=layout)
    fig.write_html('topic_clusters.html')

if __name__ == '__main__':
    main('/content/drive/MyDrive/Data Mining Project UIUC/task1/sample_data.json')
# Out:
# Topics successfully exported to topics.json

# %% [markdown]
# **Extract all categories in the business dataset**
#
# In this section, we'll extract all the topics and preprocess the review of each business using LDA. Then, we'll compare some restaurants based on their review for each rating (1-5). We'll choose mexican food restaurant to compare each restaurant than others.

# %%
# Define paths to your JSON files
business_file_path = '/content/drive/MyDrive/Data Mining Project UIUC/dataset/yelp_academic_dataset_business.json'
review_file_path = '/content/drive/MyDrive/Data Mining Project UIUC/dataset/yelp_academic_dataset_review.json'

# %%
# Function to load business information
def load_business_info(business_file):
    business_info = {}
    with open(business_file, 'r') as f:
        for line in f:
            business_json = json.loads(line)
            business_id = business_json['business_id']
            name = business_json['name'].replace('/', '&')
            business_info[business_id] = {
                'name': name,
                'stars': business_json['stars'],
                'reviews': {}
            }
    return business_info

# Function to map reviews to businesses
def map_reviews_to_business(review_file, business_info):
    with open(review_file, 'r') as f:
        for line in f:
            review_json = json.loads(line)
            business_id = review_json['business_id']
            if business_id in business_info:
                stars = int(review_json['stars'])
                review = review_json['text']
                if stars not in business_info[business_id]['reviews']:
                    business_info[business_id]['reviews'][stars] = []
                business_info[business_id]['reviews'][stars].append(review)
    return business_info

# Function to apply LDA and extract topics with word scores
def extract_lda_topics_with_scores(reviews, n_topics=5):
    vectorizer = CountVectorizer(stop_words='english', max_features=5000)
    X = vectorizer.fit_transform(reviews)
    lda = LatentDirichletAllocation(n_components=n_topics, random_state=0)
    lda.fit(X)
    topics = {}
    feature_names = vectorizer.get_feature_names_out()
    for topic_idx, topic in enumerate(lda.components_):
        top_features_ind = topic.argsort()[-10:]  # Get top 10 words for each topic
        top_features = [(feature_names[i], topic[i]) for i in top_features_ind]
        topics[f'Topic {topic_idx}'] = {word: score for word, score in top_features}
    return topics

# Function to save topics with scores for each restaurant and each rating
def save_lda_topics_with_scores_by_rating(business_info, output_path='lda_output'):
    if not os.path.exists(output_path):
        os.makedirs(output_path)
    for business_id, info in business_info.items():
        restaurant_name = info['name']
        reviews_by_rating = info['reviews']
        for rating, reviews in reviews_by_rating.items():
            if len(reviews) > 0:
                topics_with_scores = extract_lda_topics_with_scores(reviews)
                output_file = f"{output_path}/{restaurant_name}_rating_{rating}_lda_topics.json"
                with open(output_file, 'w') as f:
                    json.dump(topics_with_scores, f, indent=4)
                print(f"Saved LDA topics with scores for {restaurant_name} (Rating {rating})")

# Load business information
business_info = load_business_info(business_file_path)

# Map reviews to businesses
business_info = map_reviews_to_business(review_file_path, business_info)

# Save LDA topics with word scores for each restaurant and each rating
save_lda_topics_with_scores_by_rating(business_info, output_path='/content/drive/MyDrive/Data Mining Project UIUC/task1/lda_topics_with_scores_output')
# Out:
# Streaming output truncated to the last 5000 lines.
# Saved LDA topics with scores for Super Dragon (Rating 5)
# Saved LDA topics with scores for Desert Mission Food Bank (Rating 4)
# Saved LDA topics with scores for Desert Mission Food Bank (Rating 5)
# Saved LDA topics with scores for China Super Buffet (Rating 2)
# Saved LDA topics with scores for China Super Buffet (Rating 3)
# Saved LDA topics with scores for China Super Buffet (Rating 4)
# Saved LDA topics with scores for Stumpys Pizza (Rating 2)
# Saved LDA topics with scores for Stumpys Pizza (Rating 4)
# Saved LDA topics with scores for Stumpys Pizza (Rating 5)
# Saved LDA topics with scores for Stumpys Pizza (Rating 1)
# Saved LDA topics with scores for Stumpys Pizza (Rating 3)
# Saved LDA topics with scores for Jiffy Lube (Rating 5)
# Saved LDA topics with scores for Jiffy Lube (Rating 4)
# Saved LDA topics with scores for Jiffy Lube (Rating 2)
# Saved LDA topics with scores for Lantana Grille (Rating 3)
# Saved LDA topics with scores for Lantana Grille (Rating 4)
# Saved LDA topics with scores for Lantana Grille (Rating 2)
# Saved LDA topics with scores for Lantana Grille (Rating 1)
# Saved LDA topics with scores for Dollar Tree (Rating 4)
# Saved LDA topics with scores for BEST WESTERN Innsuites Phoenix Hotel & Suites (Rating 4)
# Saved LDA topics with scores for BEST WESTERN Innsuites Phoenix Hotel & Suites (Rating 5)
# Saved LDA topics with scores for BEST WESTERN Innsuites Phoenix Hotel & Suites (Rating 2)
# Saved LDA topics with scores for BEST WESTERN Innsuites Phoenix Hotel & Suites (Rating 3)
# Saved LDA topics with scores for Orangewood Animal Hospital PC (Rating 5)
# Saved LDA topics with scores for Orangewood Animal Hospital PC (Rating 1)
# Saved LDA topics with scores for Orangewood Animal Hospital PC (Rating 4)
# Saved LDA topics with scores for Squaw Peak Dental (Rating 4)
# Saved LDA topics with scores for Squaw Peak Dental (Rating 5)
# Saved LDA topics with scores for Squaw Peak Dental (Rating 1)
# Saved LDA topics with scores for Open Road Tours (Rating 5)
# Saved LDA topics with scores for Open Road Tours (Rating 2)
# Saved LDA topics with scores for Open Road Tours (Rating 4)
# Saved LDA topics with scores for Open Road Tours (Rating 1)
# Saved LDA topics with scores for Arizona Wholesale Auto & Truck (Rating 5)
# Saved LDA topics with scores for Arizona Wholesale Auto & Truck (Rating 1)
# Saved LDA topics with scores for Nielsen Diversified (Rating 5)
# Saved LDA topics with scores for Nielsen Diversified (Rating 2)
# Saved LDA topics with scores for North Phoenix Medical Clinic (Rating 4)
# Saved LDA topics with scores for North Phoenix Medical Clinic (Rating 1)
# Saved LDA topics with scores for North Phoenix Medical Clinic (Rating 5)
# Saved LDA topics with scores for Bamboo China Restaurant (Rating 4)
# Saved LDA topics with scores for Bamboo China Restaurant (Rating 3)
# Saved LDA topics with scores for Bamboo China Restaurant (Rating 2)
# Saved LDA topics with scores for Bamboo China Restaurant (Rating 5)
# Saved LDA topics with scores for Bamboo China Restaurant (Rating 1)
# Saved LDA topics with scores for Fiddler's Dream Coffee House (Rating 5)
# Saved LDA topics with scores for Fiddler's Dream Coffee House (Rating 4)
# Saved LDA topics with scores for Advanced Auto Service & Tire Centers (Rating 4)
# Saved LDA topics with scores for Advanced Auto Service & Tire Centers (Rating 5)
# Saved LDA topics with scores for Tuesday Morning (Rating 4)
# Saved LDA topics with scores for Tuesday Morning (Rating 5)
# Saved LDA topics with scores for Tuesday Morning (Rating 2)
# Saved LDA topics with scores for Anna's Linens (Rating 2)
# Saved LDA topics with scores for Anna's Linens (Rating 3)
# Saved LDA topics with scores for Anna's Linens (Rating 4)
# Saved LDA topics with scores for Big Bell Road Kia (Rating 1)
# Saved LDA topics with scores for Big Bell Road Kia (Rating 5)
# Saved LDA topics with scores for Jewelry Nail & Spa (Rating 4)
# Saved LDA topics with scores for Jewelry Nail & Spa (Rating 3)
# Saved LDA topics with scores for Jewelry Nail & Spa (Rating 1)
# Saved LDA topics with scores for Jewelry Nail & Spa (Rating 2)
# Saved LDA topics with scores for Walgreens (Rating 3)
# Saved LDA topics with scores for Walgreens (Rating 2)
# Saved LDA topics with scores for Walgreens (Rating 4)
# Saved LDA topics with scores for Walgreens (Rating 1)
# Saved LDA topics with scores for Blockbuster Video (Rating 1)
# Saved LDA topics with scores for Blockbuster Video (Rating 2)
# Saved LDA topics with scores for Blockbuster Video (Rating 4)
# Saved LDA topics with scores for Crystal Optical (Rating 5)
# Saved LDA topics with scores for Flamingo Palace (Rating 4)
# Saved LDA topics with scores for Flamingo Palace (Rating 3)
# Saved LDA topics with scores for Flamingo Palace (Rating 2)
# Saved LDA topics with scores for Flamingo Palace (Rating 5)
# Saved LDA topics with scores for Flamingo Palace (Rating 1)
# Saved LDA topics with scores for Southwest Bicycles (Rating 4)
# Saved LDA topics with scores for Southwest Bicycles (Rating 5)
# Saved LDA topics with scores for Southwest Bicycles (Rating 1)
# Saved LDA topics with scores for Hinrichsen Jewelers (Rating 5)
# Saved LDA topics with scores for Johnco Plumbing (Rating 4)
# Saved LDA topics with scores for Johnco Plumbing (Rating 5)
# Saved LDA topics with scores for Tammy's La Nails (Rating 5)
# Saved LDA topics with scores for Tammy's La Nails (Rating 4)
# Saved LDA topics with scores for Tammy's La Nails (Rating 2)
# Saved LDA topics with scores for Bally Total Fitness (Rating 3)
# Saved LDA topics with scores for Bally Total Fitness (Rating 1)
# Saved LDA topics with scores for Jiffy Lube (Rating 1)
# Saved LDA topics with scores for Jiffy Lube (Rating 5)
# Saved LDA topics with scores for Sport Peppers Grill (Rating 5)
# Saved LDA topics with scores for Sport Peppers Grill (Rating 3)
# Saved LDA topics with scores for Sport Peppers Grill (Rating 2)
# Saved LDA topics with scores for Sport Peppers Grill (Rating 1)
# Saved LDA topics with scores for Paradise Foothills Apartments (Rating 5)
# Saved LDA topics with scores for Paradise Foothills Apartments (Rating 1)
# Saved LDA topics with scores for Circle K Stores (Rating 3)
# Saved LDA topics with scores for Edelweiss German Deli (Rating 4)
# Saved LDA topics with scores for Edelweiss German Deli (Rating 3)
# Saved LDA topics with scores for Carl's Jr 7091 (Rating 1)
# Saved LDA topics with scores for Carl's Jr 7091 (Rating 3)
# Saved LDA topics with scores for Carl's Jr 7091 (Rating 4)
# Saved LDA topics with scores for AutoZone (Rating 4)
# Saved LDA topics with scores for AutoZone (Rating 3)
# Saved LDA topics with scores for AutoZone (Rating 5)
# Saved LDA topics with scores for Subway (Rating 2)
# Saved LDA topics with scores for Subway (Rating 1)
# Saved LDA topics with scores for Jana's Bakery (Rating 4)
# Saved LDA topics with scores for Jana's Bakery (Rating 2)
# Saved LDA topics with scores for Jana's Bakery (Rating 5)
# Saved LDA topics with scores for Jana's Bakery (Rating 3)
# Saved LDA topics with scores for Hostess Bakery Outlet (Rating 5)
# Saved LDA topics with scores for Hostess Bakery Outlet (Rating 4)
# Saved LDA topics with scores for The Home Depot (Rating 3)
# Saved LDA topics with scores for The Home Depot (Rating 5)
# Saved LDA topics with scores for The Home Depot (Rating 4)
# Saved LDA topics with scores for Ross Stores (Rating 1)
# Saved LDA topics with scores for Ross Stores (Rating 4)
# Saved LDA topics with scores for Ross Stores (Rating 3)
# Saved LDA topics with scores for Ross Stores (Rating 2)
# Saved LDA topics with scores for Cool Cuts 4 Kids (Rating 5)
# Saved LDA topics with scores for Cool Cuts 4 Kids (Rating 4)
# Saved LDA topics with scores for Pick Up Stix (Rating 3)
# Saved LDA topics with scores for Pick Up Stix (Rating 2)
# Saved LDA topics with scores for Sonic Drive-In (Rating 1)
# Saved LDA topics with scores for Sonic Drive-In (Rating 4)
# Saved LDA topics with scores for Safeway Food & Drug (Rating 2)
# Saved LDA topics with scores for Safeway Food & Drug (Rating 4)
# Saved LDA topics with scores for Safeway Food & Drug (Rating 3)
# Saved LDA topics with scores for Safeway Food & Drug (Rating 5)
# Saved LDA topics with scores for Big Lots (Rating 4)
# Saved LDA topics with scores for Big Lots (Rating 5)
# Saved LDA topics with scores for Big Lots (Rating 3)
# Saved LDA topics with scores for Big Lots (Rating 1)
# Saved LDA topics with scores for Floral Fantasy (Rating 1)
# Saved LDA topics with scores for Floral Fantasy (Rating 3)
# Saved LDA topics with scores for Floral Fantasy (Rating 2)
# Saved LDA topics with scores for Floral Fantasy (Rating 5)
# Saved LDA topics with scores for Pink Pepper Thai Cuisine (Rating 4)
# Saved LDA topics with scores for Pink Pepper Thai Cuisine (Rating 1)
# Saved LDA topics with scores for Pink Pepper Thai Cuisine (Rating 5)
# Saved LDA topics with scores for Pink Pepper Thai Cuisine (Rating 2)
# Saved LDA topics with scores for Pink Pepper Thai Cuisine (Rating 3)
# Saved LDA topics with scores for Wendy's (Rating 3)
# Saved LDA topics with scores for Wendy's (Rating 1)
# Saved LDA topics with scores for Wendy's (Rating 4)
# Saved LDA topics with scores for Famous Ray's Pizza (Rating 4)
# Saved LDA topics with scores for Famous Ray's Pizza (Rating 5)
# Saved LDA topics with scores for Famous Ray's Pizza (Rating 2)
# Saved LDA topics with scores for Famous Ray's Pizza (Rating 3)
# Saved LDA topics with scores for Famous Ray's Pizza (Rating 1)
# Saved LDA topics with scores for Eldorado Cleaners (Rating 4)
# Saved LDA topics with scores for Eldorado Cleaners (Rating 1)
# Saved LDA topics with scores for Eldorado Cleaners (Rating 5)
# Saved LDA topics with scores for Eldorado Cleaners (Rating 2)
# Saved LDA topics with scores for Bell Town Shoe Repair (Rating 5)
# Saved LDA topics with scores for Bell Town Shoe Repair (Rating 1)
# Saved LDA topics with scores for Bank of America (Rating 1)
# Saved LDA topics with scores for Bank of America (Rating 2)
# Saved LDA topics with scores for Bank of America (Rating 3)
# Saved LDA topics with scores for San Pedregal (Rating 2)
# Saved LDA topics with scores for San Pedregal (Rating 3)
# Saved LDA topics with scores for Arizona Federal Credit Union (Rating 1)
# Saved LDA topics with scores for Biagio Nail & Spa (Rating 5)
# Saved LDA topics with scores for Biagio Nail & Spa (Rating 4)
# Saved LDA topics with scores for Biagio Nail & Spa (Rating 2)
# Saved LDA topics with scores for Biagio Nail & Spa (Rating 1)
# Saved LDA topics with scores for Biagio Nail & Spa (Rating 3)
# Saved LDA topics with scores for Cr Property Services (Rating 1)
# Saved LDA topics with scores for Cr Property Services (Rating 2)
# Saved LDA topics with scores for Ramjet Racing Performance Cycles (Rating 3)
# Saved LDA topics with scores for Ramjet Racing Performance Cycles (Rating 5)
# Saved LDA topics with scores for Texaco Xpress Lube (Rating 5)
# Saved LDA topics with scores for Texaco Xpress Lube (Rating 4)
# Saved LDA topics with scores for Wizard of Odz (Rating 5)
# Saved LDA topics with scores for Taste of India (Rating 3)
# Saved LDA topics with scores for Taste of India (Rating 2)
# Saved LDA topics with scores for Taste of India (Rating 1)
# Saved LDA topics with scores for Taste of India (Rating 4)
# Saved LDA topics with scores for Smart Automotive Repair (Rating 5)
# Saved LDA topics with scores for Smart Automotive Repair (Rating 1)
# Saved LDA topics with scores for Streets of New York (Rating 3)
# Saved LDA topics with scores for Streets of New York (Rating 4)
# Saved LDA topics with scores for Streets of New York (Rating 5)
# Saved LDA topics with scores for Streets of New York (Rating 2)
# Saved LDA topics with scores for Streets of New York (Rating 1)
# Saved LDA topics with scores for Joey's California Bistro (Rating 3)
# Saved LDA topics with scores for Joey's California Bistro (Rating 1)
# Saved LDA topics with scores for Joey's California Bistro (Rating 4)
# Saved LDA topics with scores for Joey's California Bistro (Rating 5)
# Saved LDA topics with scores for Joey's California Bistro (Rating 2)
# Saved LDA topics with scores for Bamboo House (Rating 3)
# Saved LDA topics with scores for Bamboo House (Rating 5)
# Saved LDA topics with scores for Bamboo House (Rating 1)
# Saved LDA topics with scores for Bamboo House (Rating 4)
# Saved LDA topics with scores for Bamboo House (Rating 2)
# Saved LDA topics with scores for Baja Fresh Mexican Grill (Rating 5)
# Saved LDA topics with scores for Baja Fresh Mexican Grill (Rating 4)
# Saved LDA topics with scores for Baja Fresh Mexican Grill (Rating 2)
# Saved LDA topics with scores for Baja Fresh Mexican Grill (Rating 1)
# Saved LDA topics with scores for Yoga Pura (Rating 5)
# Saved LDA topics with scores for Yoga Pura (Rating 4)
# Saved LDA topics with scores for Yoga Pura (Rating 1)
# Saved LDA topics with scores for Zara Nails Plus (Rating 5)
# Saved LDA topics with scores for Zara Nails Plus (Rating 1)
# Saved LDA topics with scores for Zara Nails Plus (Rating 4)
# Saved LDA topics with scores for Eribertos Mexican Food (Rating 2)
# Saved LDA topics with scores for Eribertos Mexican Food (Rating 1)
# Saved LDA topics with scores for Eribertos Mexican Food (Rating 3)
# Saved LDA topics with scores for Eribertos Mexican Food (Rating 4)
# Saved LDA topics with scores for Eribertos Mexican Food (Rating 5)
# Saved LDA topics with scores for Crystal Creek Apartments (Rating 5)
# Saved LDA topics with scores for Crystal Creek Apartments (Rating 1)
# Saved LDA topics with scores for Crystal Creek Apartments (Rating 3)
# Saved LDA topics with scores for Peter Piper Pizza (Rating 5)
# Saved LDA topics with scores for Peter Piper Pizza (Rating 3)
# Saved LDA topics with scores for Peter Piper Pizza (Rating 4)
# Saved LDA topics with scores for Chili's Grill & Bar (Rating 5)
# Saved LDA topics with scores for Chili's Grill & Bar (Rating 3)
# Saved LDA topics with scores for Chili's Grill & Bar (Rating 1)
# Saved LDA topics with scores for Chili's Grill & Bar (Rating 4)
# Saved LDA topics with scores for Chili's Grill & Bar (Rating 2)
# Saved LDA topics with scores for Ammaccapane's Restaurant & Sports Bar (Rating 5)
# Saved LDA topics with scores for Ammaccapane's Restaurant & Sports Bar (Rating 3)
# Saved LDA topics with scores for Ammaccapane's Restaurant & Sports Bar (Rating 4)
# Saved LDA topics with scores for Ammaccapane's Restaurant & Sports Bar (Rating 1)
# Saved LDA topics with scores for Pizza Hut (Rating 1)
# Saved LDA topics with scores for Pizza Hut (Rating 3)
# Saved LDA topics with scores for Pizza Hut (Rating 5)
# Saved LDA topics with scores for FedEx Office Print & Ship Center (Rating 5)
# Saved LDA topics with scores for FedEx Office Print & Ship Center (Rating 4)
# Saved LDA topics with scores for FedEx Office Print & Ship Center (Rating 3)
# Saved LDA topics with scores for AJ's Purveyor of Fine Foods (Rating 5)
# Saved LDA topics with scores for AJ's Purveyor of Fine Foods (Rating 4)
# Saved LDA topics with scores for AJ's Purveyor of Fine Foods (Rating 3)
# Saved LDA topics with scores for LA Fitness (Rating 4)
# Saved LDA topics with scores for LA Fitness (Rating 3)
# Saved LDA topics with scores for LA Fitness (Rating 2)
# Saved LDA topics with scores for LA Fitness (Rating 1)
# Saved LDA topics with scores for LA Fitness (Rating 5)
# Saved LDA topics with scores for BeautyWorx (Rating 4)
# Saved LDA topics with scores for BeautyWorx (Rating 5)
# Saved LDA topics with scores for BeautyWorx (Rating 1)
# Saved LDA topics with scores for Wellness In Motion (Rating 5)
# Saved LDA topics with scores for Officemax (Rating 3)
# Saved LDA topics with scores for Officemax (Rating 2)
# Saved LDA topics with scores for Officemax (Rating 1)
# Saved LDA topics with scores for The UPS Store (Rating 3)
# Saved LDA topics with scores for The UPS Store (Rating 2)
# Saved LDA topics with scores for The UPS Store (Rating 1)
# Saved LDA topics with scores for A-Alyesh Chiropractic (Rating 5)
# Saved LDA topics with scores for Furniture Affair (Rating 4)
# Saved LDA topics with scores for Furniture Affair (Rating 1)
# Saved LDA topics with scores for Furniture Affair (Rating 3)
# Saved LDA topics with scores for Furniture Affair (Rating 5)
# Saved LDA topics with scores for Coronado 1.75 Cleaners (Rating 2)
# Saved LDA topics with scores for Coronado 1.75 Cleaners (Rating 3)
# Saved LDA topics with scores for Coronado 1.75 Cleaners (Rating 1)
# Saved LDA topics with scores for Coronado 1.75 Cleaners (Rating 4)
# Saved LDA topics with scores for Princess Pro Nail (Rating 4)
# Saved LDA topics with scores for Princess Pro Nail (Rating 5)
# Saved LDA topics with scores for Princess Pro Nail (Rating 3)
# Saved LDA topics with scores for Princess Pro Nail (Rating 1)
# Saved LDA topics with scores for Princess Pro Nail (Rating 2)
# Saved LDA topics with scores for Supercuts (Rating 1)
# Saved LDA topics with scores for Supercuts (Rating 4)
# Saved LDA topics with scores for Supercuts (Rating 5)
# Saved LDA topics with scores for Bell Lexus North Scottsdale (Rating 5)
# Saved LDA topics with scores for Bell Lexus North Scottsdale (Rating 1)
# Saved LDA topics with scores for Bell Lexus North Scottsdale (Rating 4)
# Saved LDA topics with scores for Boston Market (Rating 3)
# Saved LDA topics with scores for Boston Market (Rating 4)
# Saved LDA topics with scores for Boston Market (Rating 5)
# Saved LDA topics with scores for Boston Market (Rating 2)
# Saved LDA topics with scores for Sherry's Pampered Pets (Rating 5)
# Saved LDA topics with scores for Sherry's Pampered Pets (Rating 1)
# Saved LDA topics with scores for Sherry's Pampered Pets (Rating 2)
# Saved LDA topics with scores for Sherry's Pampered Pets (Rating 4)
# Saved LDA topics with scores for Einstein Bros Bagels (Rating 2)
# Saved LDA topics with scores for Einstein Bros Bagels (Rating 4)
# Saved LDA topics with scores for Einstein Bros Bagels (Rating 3)
# Saved LDA topics with scores for Einstein Bros Bagels (Rating 5)
# Saved LDA topics with scores for McDonald's (Rating 2)
# Saved LDA topics with scores for McDonald's (Rating 1)
# Saved LDA topics with scores for McDonald's (Rating 3)
# Saved LDA topics with scores for Salute Ristorante Italiano (Rating 5)
# Saved LDA topics with scores for Salute Ristorante Italiano (Rating 3)
# Saved LDA topics with scores for Salute Ristorante Italiano (Rating 4)
# Saved LDA topics with scores for Salute Ristorante Italiano (Rating 2)
# Saved LDA topics with scores for Salute Ristorante Italiano (Rating 1)
# Saved LDA topics with scores for Fletcher's Tire & Auto Service (Rating 1)
# Saved LDA topics with scores for Fletcher's Tire & Auto Service (Rating 5)
# Saved LDA topics with scores for Fletcher's Tire & Auto Service (Rating 4)
# Saved LDA topics with scores for Taco Bell (Rating 3)
# Saved LDA topics with scores for Taco Bell (Rating 4)
# Saved LDA topics with scores for Spinato's Pizza (Rating 4)
# Saved LDA topics with scores for Spinato's Pizza (Rating 5)
# Saved LDA topics with scores for Spinato's Pizza (Rating 3)
# Saved LDA topics with scores for Spinato's Pizza (Rating 2)
# Saved LDA topics with scores for Spinato's Pizza (Rating 1)
# Saved LDA topics with scores for Reach Chiropractic Centers (Rating 5)
# Saved LDA topics with scores for Carl's Jr (Rating 2)
# Saved LDA topics with scores for Carl's Jr (Rating 1)
# Saved LDA topics with scores for Phoenix First Assembly Of God (Rating 5)
# Saved LDA topics with scores for Phoenix First Assembly Of God (Rating 4)
# Saved LDA topics with scores for Phoenix First Assembly Of God (Rating 1)
# Saved LDA topics with scores for Phoenix First Assembly Of God (Rating 2)
# Saved LDA topics with scores for Network Alignment & Brakes (Rating 5)
# Saved LDA topics with scores for Network Alignment & Brakes (Rating 4)
# Saved LDA topics with scores for Salon Boulevard (Rating 1)
# Saved LDA topics with scores for Salon Boulevard (Rating 5)
# Saved LDA topics with scores for Salon Boulevard (Rating 2)
# Saved LDA topics with scores for Salon Boulevard (Rating 4)
# Saved LDA topics with scores for QuikTrip (Rating 4)
# Saved LDA topics with scores for QuikTrip (Rating 3)
# Saved LDA topics with scores for Friends of Animal Care & Control Thrift Store (Rating 3)
# Saved LDA topics with scores for Friends of Animal Care & Control Thrift Store (Rating 5)
# Saved LDA topics with scores for Friends of Animal Care & Control Thrift Store (Rating 4)
# Saved LDA topics with scores for Starbucks Coffee (Rating 4)
# Saved LDA topics with scores for Starbucks Coffee (Rating 5)
# Saved LDA topics with scores for Starbucks Coffee (Rating 3)
# Saved LDA topics with scores for Starbucks Coffee (Rating 1)
# Saved LDA topics with scores for Arrowhead Cadillac (Rating 5)
# Saved LDA topics with scores for Arrowhead Cadillac (Rating 2)
# Saved LDA topics with scores for Arrowhead Cadillac (Rating 1)
# Saved LDA topics with scores for Hi-Health (Rating 4)
# Saved LDA topics with scores for Hi-Health (Rating 2)
# Saved LDA topics with scores for Rolberto's Taco Shop (Rating 4)
# Saved LDA topics with scores for Rolberto's Taco Shop (Rating 1)
# Saved LDA topics with scores for Rolberto's Taco Shop (Rating 3)
# Saved LDA topics with scores for Rolberto's Taco Shop (Rating 5)
# Saved LDA topics with scores for Cycle Gear (Rating 2)
# Saved LDA topics with scores for Cycle Gear (Rating 4)
# Saved LDA topics with scores for Cycle Gear (Rating 1)
# Saved LDA topics with scores for Cycle Gear (Rating 5)
# Saved LDA topics with scores for Sugarloaf Animal Clinic (Rating 5)
# Saved LDA topics with scores for Sugarloaf Animal Clinic (Rating 1)
# Saved LDA topics with scores for Manuel's Mexican Restaurant (Rating 4)
# Saved LDA topics with scores for Manuel's Mexican Restaurant (Rating 5)
# Saved LDA topics with scores for Manuel's Mexican Restaurant (Rating 3)
# Saved LDA topics with scores for Manuel's Mexican Restaurant (Rating 2)
# Saved LDA topics with scores for Gulick Bros Hair (Rating 5)
# Saved LDA topics with scores for Gulick Bros Hair (Rating 3)
# Saved LDA topics with scores for Krua Thai Cuisine (Rating 3)
# Saved LDA topics with scores for Krua Thai Cuisine (Rating 5)
# Saved LDA topics with scores for Krua Thai Cuisine (Rating 4)
# Saved LDA topics with scores for Krua Thai Cuisine (Rating 1)
# Saved LDA topics with scores for Krua Thai Cuisine (Rating 2)
# Saved LDA topics with scores for Pet Safari (Rating 4)
# Saved LDA topics with scores for Pet Safari (Rating 1)
# Saved LDA topics with scores for Arizona Mini Self Storage (Rating 2)
# Saved LDA topics with scores for Arizona Mini Self Storage (Rating 4)
# Saved LDA topics with scores for Arizona Mini Self Storage (Rating 3)
# Saved LDA topics with scores for Arizona Mini Self Storage (Rating 5)
# Saved LDA topics with scores for North China Restaurant (Rating 4)
# Saved LDA topics with scores for North China Restaurant (Rating 5)
# Saved LDA topics with scores for North China Restaurant (Rating 3)
# Saved LDA topics with scores for North China Restaurant (Rating 1)
# Saved LDA topics with scores for North China Restaurant (Rating 2)
# Saved LDA topics with scores for Anthony Lee Nails (Rating 1)
# Saved LDA topics with scores for Anthony Lee Nails (Rating 5)
# Saved LDA topics with scores for Anthony Lee Nails (Rating 4)
# Saved LDA topics with scores for Anthony Lee Nails (Rating 3)
# Saved LDA topics with scores for Panda Express (Rating 4)
# Saved LDA topics with scores for Panda Express (Rating 5)
# Saved LDA topics with scores for Panda Express (Rating 3)
# Saved LDA topics with scores for Panda Express (Rating 2)
# Saved LDA topics with scores for Dairy Queen (Rating 3)
# Saved LDA topics with scores for Dairy Queen (Rating 1)
# Saved LDA topics with scores for Dairy Queen (Rating 2)
# Saved LDA topics with scores for Dairy Queen (Rating 5)
# Saved LDA topics with scores for Backpro Chiropractic & Nutrition (Rating 5)
# Saved LDA topics with scores for Uncle Bob's Self Storage (Rating 1)
# Saved LDA topics with scores for Uncle Bob's Self Storage (Rating 5)
# Saved LDA topics with scores for Uncle Bob's Self Storage (Rating 3)
# Saved LDA topics with scores for Chuy's Mesquite Broiler (Rating 5)
# Saved LDA topics with scores for Chuy's Mesquite Broiler (Rating 4)
# Saved LDA topics with scores for Chuy's Mesquite Broiler (Rating 3)
# Saved LDA topics with scores for Chuy's Mesquite Broiler (Rating 2)
# Saved LDA topics with scores for Chuy's Mesquite Broiler (Rating 1)
# Saved LDA topics with scores for Firestone Complete Auto Care (Rating 1)
# Saved LDA topics with scores for Firestone Complete Auto Care (Rating 5)
# Saved LDA topics with scores for Firestone Complete Auto Care (Rating 2)
# Saved LDA topics with scores for Pinky's Cafe (Rating 4)
# Saved LDA topics with scores for Pinky's Cafe (Rating 2)
# Saved LDA topics with scores for Pinky's Cafe (Rating 3)
# Saved LDA topics with scores for Pinky's Cafe (Rating 1)
# Saved LDA topics with scores for Lookout Mountain Veterinary Clinic (Rating 5)
# Saved LDA topics with scores for Lookout Mountain Veterinary Clinic (Rating 1)
# Saved LDA topics with scores for Lookout Mountain Veterinary Clinic (Rating 4)
# Saved LDA topics with scores for Sabroso Fresh Mexican Grill (Rating 2)
# Saved LDA topics with scores for Sabroso Fresh Mexican Grill (Rating 3)
# Saved LDA topics with scores for Sabroso Fresh Mexican Grill (Rating 1)
# Saved LDA topics with scores for Sabroso Fresh Mexican Grill (Rating 4)
# Saved LDA topics with scores for Sabroso Fresh Mexican Grill (Rating 5)
# Saved LDA topics with scores for Sincerely Yours Salon - Hair! (Rating 4)
# Saved LDA topics with scores for Sincerely Yours Salon - Hair! (Rating 5)
# Saved LDA topics with scores for Sincerely Yours Salon - Hair! (Rating 1)
# Saved LDA topics with scores for Lovejoys Kansas City Bar-B-Q (Rating 1)
# Saved LDA topics with scores for Lovejoys Kansas City Bar-B-Q (Rating 4)
# Saved LDA topics with scores for Lovejoys Kansas City Bar-B-Q (Rating 2)
# Saved LDA topics with scores for Lovejoys Kansas City Bar-B-Q (Rating 3)
# Saved LDA topics with scores for Dragon Bowl (Rating 3)
# Saved LDA topics with scores for Dragon Bowl (Rating 1)
# Saved LDA topics with scores for Dragon Bowl (Rating 2)
# Saved LDA topics with scores for Dragon Bowl (Rating 4)
# Saved LDA topics with scores for Dragon Bowl (Rating 5)
# Saved LDA topics with scores for Moon Valley Custom Cleaners (Rating 4)
# Saved LDA topics with scores for Moon Valley Custom Cleaners (Rating 1)
# Saved LDA topics with scores for Moon Valley Custom Cleaners (Rating 2)
# Saved LDA topics with scores for QuikTrip (Rating 5)
# Saved LDA topics with scores for QuikTrip (Rating 2)
# Saved LDA topics with scores for QuikTrip (Rating 3)
# Saved LDA topics with scores for QuikTrip (Rating 4)
# Saved LDA topics with scores for National Memorial Cemetery of Arizona (Rating 5)
# Saved LDA topics with scores for Domino's Pizza (Rating 1)
# Saved LDA topics with scores for Domino's Pizza (Rating 5)
# Saved LDA topics with scores for Domino's Pizza (Rating 2)
# Saved LDA topics with scores for Domino's Pizza (Rating 4)
# Saved LDA topics with scores for Domino's Pizza (Rating 3)
# Saved LDA topics with scores for Deer Creek Animal Hospital (Rating 5)
# Saved LDA topics with scores for Deer Creek Animal Hospital (Rating 3)
# Saved LDA topics with scores for Deer Creek Animal Hospital (Rating 4)
# Saved LDA topics with scores for Deer Creek Animal Hospital (Rating 1)
# Saved LDA topics with scores for Fancy Nails & Tanning (Rating 5)
# Saved LDA topics with scores for Fancy Nails & Tanning (Rating 4)
# Saved LDA topics with scores for Fancy Nails & Tanning (Rating 3)
# Saved LDA topics with scores for Fancy Nails & Tanning (Rating 1)
# Saved LDA topics with scores for Dairy Queen (Rating 3)
# Saved LDA topics with scores for Dairy Queen (Rating 4)
# Saved LDA topics with scores for Dairy Queen (Rating 1)
# Saved LDA topics with scores for Dairy Queen (Rating 5)
# Saved LDA topics with scores for Cave Creek Wines (Rating 4)
# Saved LDA topics with scores for Cave Creek Wines (Rating 5)
# Saved LDA topics with scores for Candy Store (Rating 3)
# Saved LDA topics with scores for Candy Store (Rating 4)
# Saved LDA topics with scores for Candy Store (Rating 1)
# Saved LDA topics with scores for Candy Store (Rating 5)
# Saved LDA topics with scores for Desert Gardens Nursery (Rating 5)
# Saved LDA topics with scores for Desert Gardens Nursery (Rating 4)
# Saved LDA topics with scores for Desert Gardens Nursery (Rating 2)
# Saved LDA topics with scores for Desert Gardens Nursery (Rating 3)
# Saved LDA topics with scores for Subway (Rating 1)
# Saved LDA topics with scores for Subway (Rating 2)
# Saved LDA topics with scores for Subway (Rating 4)
# Saved LDA topics with scores for Subway (Rating 3)
# Saved LDA topics with scores for Doggie Doos Grooming (Rating 4)
# Saved LDA topics with scores for Doggie Doos Grooming (Rating 5)
# Saved LDA topics with scores for Larry's Place (Rating 3)
# Saved LDA topics with scores for Larry's Place (Rating 5)
# Saved LDA topics with scores for Larry's Place (Rating 4)
# Saved LDA topics with scores for Valvoline Instant Oil Change (Rating 5)
# Saved LDA topics with scores for Valvoline Instant Oil Change (Rating 4)
# Saved LDA topics with scores for Valvoline Instant Oil Change (Rating 1)
# Saved LDA topics with scores for Valvoline Instant Oil Change (Rating 2)
# Saved LDA topics with scores for Bashas (Rating 4)
# Saved LDA topics with scores for Bashas (Rating 5)
# Saved LDA topics with scores for Bashas (Rating 1)
# Saved LDA topics with scores for Bashas (Rating 3)
# Saved LDA topics with scores for Bashas (Rating 2)
# Saved LDA topics with scores for Quiznos (Rating 4)
# Saved LDA topics with scores for Quiznos (Rating 5)
# Saved LDA topics with scores for Big O Tire Stores (Rating 1)
# Saved LDA topics with scores for Big O Tire Stores (Rating 5)
# Saved LDA topics with scores for Gallagher's (Rating 4)
# Saved LDA topics with scores for Gallagher's (Rating 1)
# Saved LDA topics with scores for Gallagher's (Rating 5)
# Saved LDA topics with scores for Gallagher's (Rating 3)
# Saved LDA topics with scores for Gallagher's (Rating 2)
# Saved LDA topics with scores for Integrity Air Conditioning & Heating LLC (Rating 4)
# Saved LDA topics with scores for Integrity Air Conditioning & Heating LLC (Rating 2)
# Saved LDA topics with scores for Integrity Air Conditioning & Heating LLC (Rating 1)
# Saved LDA topics with scores for Integrity Air Conditioning & Heating LLC (Rating 5)
# Saved LDA topics with scores for Firestone Complete Auto Care (Rating 5)
# Saved LDA topics with scores for Firestone Complete Auto Care (Rating 4)
# Saved LDA topics with scores for Firestone Complete Auto Care (Rating 3)
# Saved LDA topics with scores for Firestone Complete Auto Care (Rating 1)
# Saved LDA topics with scores for Firestone Complete Auto Care (Rating 2)
# Saved LDA topics with scores for Boulder Falls Pet Resort (Rating 4)
# Saved LDA topics with scores for Boulder Falls Pet Resort (Rating 1)
# Saved LDA topics with scores for Boulder Falls Pet Resort (Rating 5)
# Saved LDA topics with scores for Capri Nails (Rating 5)
# Saved LDA topics with scores for Capri Nails (Rating 4)
# Saved LDA topics with scores for Capri Nails (Rating 3)
# Saved LDA topics with scores for Capri Nails (Rating 1)
# Saved LDA topics with scores for QuikTrip (Rating 5)
# Saved LDA topics with scores for Mi Pueblo Mexican Food (Rating 3)
# Saved LDA topics with scores for Mi Pueblo Mexican Food (Rating 4)
# Saved LDA topics with scores for Mi Pueblo Mexican Food (Rating 5)
# Saved LDA topics with scores for Mi Pueblo Mexican Food (Rating 2)
# Saved LDA topics with scores for Mi Pueblo Mexican Food (Rating 1)
# Saved LDA topics with scores for Little Caesars Pizza (Rating 4)
# Saved LDA topics with scores for Little Caesars Pizza (Rating 3)
# Saved LDA topics with scores for Circle K (Rating 4)
# Saved LDA topics with scores for Circle K (Rating 1)
# Saved LDA topics with scores for Atd Automotive (Rating 5)
# Saved LDA topics with scores for Cousins Subs (Rating 2)
# Saved LDA topics with scores for Cousins Subs (Rating 1)
# Saved LDA topics with scores for Cousins Subs (Rating 3)
# Saved LDA topics with scores for Cousins Subs (Rating 5)
# Saved LDA topics with scores for Stool & Dinette Factory (Rating 5)
# Saved LDA topics with scores for Stool & Dinette Factory (Rating 4)
# Saved LDA topics with scores for Stool & Dinette Factory (Rating 2)
# Saved LDA topics with scores for First Credit Union (Rating 1)
# Saved LDA topics with scores for First Credit Union (Rating 5)
# Saved LDA topics with scores for My Nail Salon (Rating 5)
# Saved LDA topics with scores for My Nail Salon (Rating 4)
# Saved LDA topics with scores for My Nail Salon (Rating 2)
# Saved LDA topics with scores for My Nail Salon (Rating 1)
# Saved LDA topics with scores for My Nail Salon (Rating 3)
# Saved LDA topics with scores for PetSmart (Rating 4)
# Saved LDA topics with scores for PetSmart (Rating 1)
# Saved LDA topics with scores for PetSmart (Rating 5)
# Saved LDA topics with scores for PetSmart (Rating 3)
# Saved LDA topics with scores for Aaron Brothers Art & (Rating 4)
# Saved LDA topics with scores for Aaron Brothers Art & (Rating 5)
# Saved LDA topics with scores for Stacy's Hallmark (Rating 4)
# Saved LDA topics with scores for Stacy's Hallmark (Rating 5)
# Saved LDA topics with scores for Stacy's Hallmark (Rating 1)
# Saved LDA topics with scores for Taco Bell (Rating 2)
# Saved LDA topics with scores for Taco Bell (Rating 5)
# Saved LDA topics with scores for Taco Bell (Rating 4)
# Saved LDA topics with scores for Taco Bell (Rating 3)
# Saved LDA topics with scores for TCBY Yogurt (Rating 4)
# Saved LDA topics with scores for Starbucks (Rating 5)
# Saved LDA topics with scores for Starbucks (Rating 4)
# Saved LDA topics with scores for Starbucks (Rating 3)
# Saved LDA topics with scores for Banfield Pet Hospital (Rating 5)
# Saved LDA topics with scores for Banfield Pet Hospital (Rating 1)
# Saved LDA topics with scores for Ambassador Fine Cigars (Rating 5)
# Saved LDA topics with scores for Panda Express (Rating 3)
# Saved LDA topics with scores for Panda Express (Rating 5)
# Saved LDA topics with scores for Panda Express (Rating 1)
# Saved LDA topics with scores for Panda Express (Rating 2)
# Saved LDA topics with scores for Blimpie Subs & Salads (Rating 5)
# Saved LDA topics with scores for Blimpie Subs & Salads (Rating 4)
# Saved LDA topics with scores for Blimpie Subs & Salads (Rating 2)
# Saved LDA topics with scores for Staples (Rating 5)
# Saved LDA topics with scores for Staples (Rating 2)
# Saved LDA topics with scores for Staples (Rating 4)
# Saved LDA topics with scores for Bed Bath & Beyond (Rating 4)
# Saved LDA topics with scores for Bed Bath & Beyond (Rating 5)
# Saved LDA topics with scores for Bed Bath & Beyond (Rating 3)
# Saved LDA topics with scores for Bed Bath & Beyond (Rating 1)
# Saved LDA topics with scores for Toy Anxiety (Rating 5)
# Saved LDA topics with scores for Toy Anxiety (Rating 4)
# Saved LDA topics with scores for Yasha From Russia (Rating 4)
# Saved LDA topics with scores for Yasha From Russia (Rating 5)
# Saved LDA topics with scores for Yasha From Russia (Rating 2)
# Saved LDA topics with scores for Yasha From Russia (Rating 3)
# Saved LDA topics with scores for Yasha From Russia (Rating 1)
# Saved LDA topics with scores for Steve's Barber Shop (Rating 5)
# Saved LDA topics with scores for Steve's Barber Shop (Rating 4)
# Saved LDA topics with scores for Camelback Womens Health (Rating 1)
# Saved LDA topics with scores for Camelback Womens Health (Rating 5)
# Saved LDA topics with scores for Camelback Womens Health (Rating 2)
# Saved LDA topics with scores for Camelback Womens Health (Rating 4)
# Saved LDA topics with scores for Camelback Womens Health (Rating 3)
# Saved LDA topics with scores for Arboleda Brechner (Rating 5)
# Saved LDA topics with scores for Arboleda Brechner (Rating 1)
# Saved LDA topics with scores for Men's Wearhouse and Tux (Rating 5)
# Saved LDA topics with scores for Men's Wearhouse and Tux (Rating 3)
# Saved LDA topics with scores for Men's Wearhouse and Tux (Rating 1)
# Saved LDA topics with scores for Leslie's Swimming Pool Supplies (Rating 5)
# Saved LDA topics with scores for Leslie's Swimming Pool Supplies (Rating 1)
# Saved LDA topics with scores for Camelback Women's Health (Rating 4)
# Saved LDA topics with scores for Camelback Women's Health (Rating 1)
# Saved LDA topics with scores for Camelback Women's Health (Rating 5)
# Saved LDA topics with scores for Camelback Women's Health (Rating 2)
# Saved LDA topics with scores for Camelback Women's Health (Rating 3)
# Saved LDA topics with scores for Entegrity Ear Nose & Throat Specialists (Rating 3)
# Saved LDA topics with scores for Entegrity Ear Nose & Throat Specialists (Rating 5)
# Saved LDA topics with scores for Entegrity Ear Nose & Throat Specialists (Rating 2)
# Saved LDA topics with scores for Entegrity Ear Nose & Throat Specialists (Rating 1)
# Saved LDA topics with scores for Entegrity Ear Nose & Throat Specialists (Rating 4)
# Saved LDA topics with scores for Paradise Valley Family Medicine (Rating 5)
# Saved LDA topics with scores for Paradise Valley Family Medicine (Rating 4)
# Saved LDA topics with scores for Paradise Valley Family Medicine (Rating 3)
# Saved LDA topics with scores for Paradise Valley Family Medicine (Rating 1)
# Saved LDA topics with scores for Whole Foods Market (Rating 4)
# Saved LDA topics with scores for Whole Foods Market (Rating 3)
# Saved LDA topics with scores for Whole Foods Market (Rating 2)
# Saved LDA topics with scores for Whole Foods Market (Rating 5)
# Saved LDA topics with scores for Whole Foods Market (Rating 1)
# Saved LDA topics with scores for Imagination Avenue (Rating 4)
# Saved LDA topics with scores for Imagination Avenue (Rating 5)
# Saved LDA topics with scores for Imagination Avenue (Rating 3)
# Saved LDA topics with scores for Imagination Avenue (Rating 1)
# Saved LDA topics with scores for Imagination Avenue (Rating 2)
# Saved LDA topics with scores for Beauty Brands (Rating 4)
# Saved LDA topics with scores for Beauty Brands (Rating 5)
# Saved LDA topics with scores for Verizon Wireless (Rating 5)
# Saved LDA topics with scores for Verizon Wireless (Rating 1)
# Saved LDA topics with scores for Verizon Wireless (Rating 2)
# Saved LDA topics with scores for Verizon Wireless (Rating 4)
# Saved LDA topics with scores for AquaTouch (Rating 5)
# Saved LDA topics with scores for AquaTouch (Rating 1)
# Saved LDA topics with scores for AquaTouch (Rating 4)
# Saved LDA topics with scores for Blooze (Rating 4)
# Saved LDA topics with scores for Blooze (Rating 3)
# Saved LDA topics with scores for Blooze (Rating 5)
# Saved LDA topics with scores for Blooze (Rating 2)
# Saved LDA topics with scores for Little Peking (Rating 5)
# Saved LDA topics with scores for Little Peking (Rating 3)
# Saved LDA topics with scores for Little Peking (Rating 4)
# Saved LDA topics with scores for Little Peking (Rating 2)
# Saved LDA topics with scores for Little Peking (Rating 1)
# Saved LDA topics with scores for Pick Up Stix (Rating 4)
# Saved LDA topics with scores for Pick Up Stix (Rating 1)
# Saved LDA topics with scores for Adriana K Holy, MD (Rating 4)
# Saved LDA topics with scores for Adriana K Holy, MD (Rating 1)
# Saved LDA topics with scores for Adriana K Holy, MD (Rating 2)
# Saved LDA topics with scores for Adriana K Holy, MD (Rating 5)
# Saved LDA topics with scores for Steven K. Ingersoll, DDS (Rating 5)
# Saved LDA topics with scores for St George Antiochian Orthodox Church (Rating 4)
# Saved LDA topics with scores for St George Antiochian Orthodox Church (Rating 5)
# Saved LDA topics with scores for St George Antiochian Orthodox Church (Rating 1)
# Saved LDA topics with scores for St George Antiochian Orthodox Church (Rating 2)
# Saved LDA topics with scores for Sonora Quest Laboratories (Rating 5)
# Saved LDA topics with scores for Sonora Quest Laboratories (Rating 3)
# Saved LDA topics with scores for Major Appliance Parts Company & Service (Rating 1)
# Saved LDA topics with scores for Major Appliance Parts Company & Service (Rating 5)
# Saved LDA topics with scores for Regus (Rating 1)
# Saved LDA topics with scores for Regus (Rating 5)
# Saved LDA topics with scores for AMF Shea Village Lanes (Rating 5)
# Saved LDA topics with scores for AMF Shea Village Lanes (Rating 4)
# Saved LDA topics with scores for Annie's Pet Parlor (Rating 4)
# Saved LDA topics with scores for Annie's Pet Parlor (Rating 1)
# Saved LDA topics with scores for Annie's Pet Parlor (Rating 5)
# Saved LDA topics with scores for Federicos Mexican Food (Rating 4)
# Saved LDA topics with scores for Federicos Mexican Food (Rating 1)
# Saved LDA topics with scores for Federicos Mexican Food (Rating 3)
# Saved LDA topics with scores for Federicos Mexican Food (Rating 5)
# Saved LDA topics with scores for Alpine Boardsports (Rating 4)
# Saved LDA topics with scores for Alpine Boardsports (Rating 5)
# Saved LDA topics with scores for Paradise Hills Barbers (Rating 5)
# Saved LDA topics with scores for Pizza Hut (Rating 1)
# Saved LDA topics with scores for Pizza Hut (Rating 5)
# Saved LDA topics with scores for Pizza Hut (Rating 4)
# Saved LDA topics with scores for Pizza Hut (Rating 2)
# Saved LDA topics with scores for Bashas'  (Rating 4)
# Saved LDA topics with scores for Bashas'  (Rating 2)
# Saved LDA topics with scores for Bashas'  (Rating 1)
# Saved LDA topics with scores for Bashas'  (Rating 5)
# Saved LDA topics with scores for Walgreens (Rating 5)
# Saved LDA topics with scores for Walgreens (Rating 4)
# Saved LDA topics with scores for Walgreens (Rating 2)
# Saved LDA topics with scores for Uncle Sam's (Rating 3)
# Saved LDA topics with scores for Uncle Sam's (Rating 4)
# Saved LDA topics with scores for Uncle Sam's (Rating 5)
# Saved LDA topics with scores for Uncle Sam's (Rating 2)
# Saved LDA topics with scores for Uncle Sam's (Rating 1)
# Saved LDA topics with scores for Shea Animal Hospital (Rating 5)
# Saved LDA topics with scores for Shea Animal Hospital (Rating 1)
# Saved LDA topics with scores for Shea Chiropractic Clinic PC (Rating 5)
# Saved LDA topics with scores for Playa Bar and Grill (Rating 4)
# Saved LDA topics with scores for Playa Bar and Grill (Rating 5)
# Saved LDA topics with scores for Church's Fried Chicken (Rating 3)
# Saved LDA topics with scores for Church's Fried Chicken (Rating 1)
# Saved LDA topics with scores for Church's Fried Chicken (Rating 4)
# Saved LDA topics with scores for Church's Fried Chicken (Rating 2)
# Saved LDA topics with scores for Subway (Rating 4)
# Saved LDA topics with scores for Subway (Rating 2)
# Saved LDA topics with scores for Subway (Rating 1)
# Saved LDA topics with scores for Subway (Rating 3)
# Saved LDA topics with scores for Subway (Rating 5)
# Saved LDA topics with scores for Michelina's Ristorante Costa Campagnia (Rating 3)
# Saved LDA topics with scores for Michelina's Ristorante Costa Campagnia (Rating 5)
# Saved LDA topics with scores for Michelina's Ristorante Costa Campagnia (Rating 4)
# Saved LDA topics with scores for Michelina's Ristorante Costa Campagnia (Rating 2)
# Saved LDA topics with scores for Michelina's Ristorante Costa Campagnia (Rating 1)
# Saved LDA topics with scores for Silver Touch Car Wash (Rating 4)
# Saved LDA topics with scores for Silver Touch Car Wash (Rating 5)
# Saved LDA topics with scores for Silver Touch Car Wash (Rating 1)
# Saved LDA topics with scores for A Razors Edge Window Tinting (Rating 4)
# Saved LDA topics with scores for A Razors Edge Window Tinting (Rating 1)
# Saved LDA topics with scores for A Razors Edge Window Tinting (Rating 5)
# Saved LDA topics with scores for Food City (Rating 4)
# Saved LDA topics with scores for Food City (Rating 3)
# Saved LDA topics with scores for Food City (Rating 5)
# Saved LDA topics with scores for Mesquite Branch Library (Rating 5)
# Saved LDA topics with scores for Mesquite Branch Library (Rating 4)
# Saved LDA topics with scores for Mesquite Branch Library (Rating 2)
# Saved LDA topics with scores for Mesquite Branch Library (Rating 3)
# Saved LDA topics with scores for AAA Arizona (Rating 4)
# Saved LDA topics with scores for AAA Arizona (Rating 5)
# Saved LDA topics with scores for Red Devil (Rating 4)
# Saved LDA topics with scores for Red Devil (Rating 5)
# Saved LDA topics with scores for Red Devil (Rating 3)
# Saved LDA topics with scores for Red Devil (Rating 2)
# Saved LDA topics with scores for Red Devil (Rating 1)
# Saved LDA topics with scores for Micor EDC Inc (Rating 5)
# Saved LDA topics with scores for David's Bridal (Rating 4)
# Saved LDA topics with scores for David's Bridal (Rating 1)
# Saved LDA topics with scores for David's Bridal (Rating 5)
# Saved LDA topics with scores for David's Bridal (Rating 2)
# Saved LDA topics with scores for David's Bridal (Rating 3)
# Saved LDA topics with scores for The Barber Shop (Rating 5)
# Saved LDA topics with scores for The Barber Shop (Rating 4)
# Saved LDA topics with scores for The Barber Shop (Rating 1)
# Saved LDA topics with scores for Aquatec Fountains (Rating 1)
# Saved LDA topics with scores for Aquatec Fountains (Rating 4)
# Saved LDA topics with scores for Pot World (Rating 4)
# Saved LDA topics with scores for Pot World (Rating 1)
# Saved LDA topics with scores for Home Fabrics (Rating 4)
# Saved LDA topics with scores for Home Fabrics (Rating 5)
# Saved LDA topics with scores for Home Fabrics (Rating 2)
# Saved LDA topics with scores for Jerry's Golf Balls (Rating 5)
# Saved LDA topics with scores for Old Navy Clothing (Rating 4)
# Saved LDA topics with scores for Old Navy Clothing (Rating 2)
# Saved LDA topics with scores for Gab's Auto Repair (Rating 5)
# Saved LDA topics with scores for Wagon Yard (Rating 4)
# Saved LDA topics with scores for Wagon Yard (Rating 3)
# Saved LDA topics with scores for Wagon Yard (Rating 5)
# Saved LDA topics with scores for Wagon Yard (Rating 1)
# Saved LDA topics with scores for Auto Body World (Rating 5)
# Saved LDA topics with scores for Auto Body World (Rating 1)
# Saved LDA topics with scores for The Buzz Boy's (Rating 5)
# Saved LDA topics with scores for The Buzz Boy's (Rating 4)
# Saved LDA topics with scores for The Buzz Boy's (Rating 3)
# Saved LDA topics with scores for It's All Goodz (Rating 4)
# Saved LDA topics with scores for It's All Goodz (Rating 3)
# Saved LDA topics with scores for Bella Nails (Rating 5)
# Saved LDA topics with scores for Bella Nails (Rating 3)
# Saved LDA topics with scores for Bella Nails (Rating 4)
# Saved LDA topics with scores for Bella Nails (Rating 2)
# Saved LDA topics with scores for Bella Nails (Rating 1)
# Saved LDA topics with scores for Pigments of Imagination (Rating 3)
# Saved LDA topics with scores for Pigments of Imagination (Rating 5)
# Saved LDA topics with scores for Pigments of Imagination (Rating 2)
# Saved LDA topics with scores for Subway (Rating 3)
# Saved LDA topics with scores for Subway (Rating 1)
# Saved LDA topics with scores for Subway (Rating 5)
# Saved LDA topics with scores for Subway (Rating 4)
# Saved LDA topics with scores for Desert Schools Federal Credit Union (Rating 5)
# Saved LDA topics with scores for Desert Schools Federal Credit Union (Rating 3)
# Saved LDA topics with scores for Desert Schools Federal Credit Union (Rating 2)
# Saved LDA topics with scores for Desert Schools Federal Credit Union (Rating 1)
# Saved LDA topics with scores for Desert Schools Federal Credit Union (Rating 4)
# Saved LDA topics with scores for Desert Schools Federal Credit Union (Rating 1)
# Saved LDA topics with scores for Goodwill of Central Arizona (Rating 5)
# Saved LDA topics with scores for Goodwill of Central Arizona (Rating 4)
# Saved LDA topics with scores for Goodwill of Central Arizona (Rating 1)
# Saved LDA topics with scores for Goodwill of Central Arizona (Rating 3)
# Saved LDA topics with scores for MAC Cosmetics (Rating 5)
# Saved LDA topics with scores for MAC Cosmetics (Rating 4)
# Saved LDA topics with scores for MAC Cosmetics (Rating 2)
# Saved LDA topics with scores for Walmart Supercenter (Rating 3)
# Saved LDA topics with scores for Walmart Supercenter (Rating 2)
# Saved LDA topics with scores for Walmart Supercenter (Rating 1)
# Saved LDA topics with scores for Walmart Supercenter (Rating 4)
# Saved LDA topics with scores for Walmart Supercenter (Rating 5)
# Saved LDA topics with scores for Samurai Sam's Teriyaki Grill (Rating 5)
# Saved LDA topics with scores for Samurai Sam's Teriyaki Grill (Rating 1)
# Saved LDA topics with scores for Samurai Sam's Teriyaki Grill (Rating 4)
# Saved LDA topics with scores for Office Max (Rating 4)
# Saved LDA topics with scores for Office Max (Rating 2)
# Saved LDA topics with scores for A A Wok (Rating 3)
# Saved LDA topics with scores for A A Wok (Rating 2)
# Saved LDA topics with scores for A A Wok (Rating 5)
# Saved LDA topics with scores for A A Wok (Rating 4)
# Saved LDA topics with scores for Above and Beyond Nails (Rating 5)
# ...
# Saved LDA topics with scores for I-Mart (Rating 3)
# Saved LDA topics with scores for I-Mart (Rating 5)
# Saved LDA topics with scores for I-Mart (Rating 2)
# Saved LDA topics with scores for I-Mart (Rating 4)
# Saved LDA topics with scores for I-Mart (Rating 1)
# Saved LDA topics with scores for Regis Salon (Rating 5)
# Saved LDA topics with scores for Kisses Nails (Rating 2)
# Saved LDA topics with scores for Kisses Nails (Rating 4)
# Saved LDA topics with scores for Kisses Nails (Rating 5)
# Saved LDA topics with scores for Kisses Nails (Rating 1)
# Saved LDA topics with scores for Nailspa Expose (Rating 5)
# Saved LDA topics with scores for Nailspa Expose (Rating 4)
# Saved LDA topics with scores for Nailspa Expose (Rating 1)
# Saved LDA topics with scores for Nailspa Expose (Rating 2)
# Saved LDA topics with scores for Sunglass Hut International (Rating 1)
# Saved LDA topics with scores for Sunglass Hut International (Rating 4)
# Saved LDA topics with scores for Bank of America (Rating 3)
# Saved LDA topics with scores for Bank of America (Rating 1)
# Saved LDA topics with scores for Jack In the Box (Rating 3)
# Saved LDA topics with scores for Jack In the Box (Rating 1)
# Saved LDA topics with scores for Leslie R Fish, DDS (Rating 5)
# Saved LDA topics with scores for Leslie R Fish, DDS (Rating 1)
# Saved LDA topics with scores for Leslie R Fish, DDS (Rating 2)
# Saved LDA topics with scores for Ross Dress For Less (Rating 3)
# Saved LDA topics with scores for Ross Dress For Less (Rating 2)
# Saved LDA topics with scores for Ross Dress For Less (Rating 4)
# Saved LDA topics with scores for Ross Dress For Less (Rating 1)
# Saved LDA topics with scores for LensCrafters (Rating 4)
# Saved LDA topics with scores for LensCrafters (Rating 1)
# Saved LDA topics with scores for LensCrafters (Rating 3)
# Saved LDA topics with scores for LensCrafters (Rating 2)
# Saved LDA topics with scores for LensCrafters (Rating 5)
# Saved LDA topics with scores for Batteries Plus (Rating 5)
# Saved LDA topics with scores for Batteries Plus (Rating 4)
# Saved LDA topics with scores for 1st Pet Veterinary Centers (Rating 5)
# Saved LDA topics with scores for 1st Pet Veterinary Centers (Rating 2)
# Saved LDA topics with scores for 1st Pet Veterinary Centers (Rating 4)
# Saved LDA topics with scores for 1st Pet Veterinary Centers (Rating 1)
# Saved LDA topics with scores for Childtime (Rating 1)
# Saved LDA topics with scores for Childtime (Rating 5)
# Saved LDA topics with scores for Waterfront Grill (Rating 2)
# Saved LDA topics with scores for Waterfront Grill (Rating 4)
# Saved LDA topics with scores for Waterfront Grill (Rating 1)
# Saved LDA topics with scores for Desert Oasis Aquatics Center (Rating 3)
# Saved LDA topics with scores for Desert Oasis Aquatics Center (Rating 5)
# Saved LDA topics with scores for Desert Oasis Aquatics Center (Rating 4)
# Saved LDA topics with scores for The Yankee Clipper Barber Shop (Rating 4)
# Saved LDA topics with scores for The Yankee Clipper Barber Shop (Rating 5)
# Saved LDA topics with scores for Taco Bell (Rating 3)
# Saved LDA topics with scores for Taco Bell (Rating 4)
# Saved LDA topics with scores for Taco Bell (Rating 2)
# Saved LDA topics with scores for Taco Bell (Rating 1)
# Saved LDA topics with scores for Associated Dental (Rating 1)
# Saved LDA topics with scores for Associated Dental (Rating 3)
# Saved LDA topics with scores for Manila Sunrise Sari-Sari Store (Rating 3)
# Saved LDA topics with scores for Manila Sunrise Sari-Sari Store (Rating 5)
# Saved LDA topics with scores for Cartridge World (Rating 5)
# Saved LDA topics with scores for Cartridge World (Rating 4)
# Saved LDA topics with scores for Cartridge World (Rating 1)
# Saved LDA topics with scores for Crystal Springs Car Wash (Rating 4)
# Saved LDA topics with scores for Crystal Springs Car Wash (Rating 5)
# Saved LDA topics with scores for Crystal Springs Car Wash (Rating 2)
# Saved LDA topics with scores for Crystal Springs Car Wash (Rating 1)
# Saved LDA topics with scores for Paragon Dance Center (Rating 4)
# Saved LDA topics with scores for Paragon Dance Center (Rating 5)
# Saved LDA topics with scores for Paragon Dance Center (Rating 1)
# Saved LDA topics with scores for Paragon Dance Center (Rating 3)
# Saved LDA topics with scores for Hollywood Beauty Supply (Rating 4)
# Saved LDA topics with scores for Hollywood Beauty Supply (Rating 3)
# Saved LDA topics with scores for Hollywood Beauty Supply (Rating 5)
# Saved LDA topics with scores for Hollywood Beauty Supply (Rating 1)
# Saved LDA topics with scores for Burger King (Rating 1)
# Saved LDA topics with scores for Burger King (Rating 2)
# Saved LDA topics with scores for Burger King (Rating 4)
# Saved LDA topics with scores for Burger King (Rating 3)
# Saved LDA topics with scores for Burger King (Rating 5)
# Saved LDA topics with scores for Sunwest Dental Centers (Rating 4)
# Saved LDA topics with scores for Sunwest Dental Centers (Rating 1)
# Saved LDA topics with scores for Sunwest Dental Centers (Rating 5)
# Saved LDA topics with scores for Full Circle Auto Wash (Rating 4)
# Saved LDA topics with scores for Full Circle Auto Wash (Rating 2)
# Saved LDA topics with scores for Full Circle Auto Wash (Rating 3)
# Saved LDA topics with scores for Full Circle Auto Wash (Rating 1)
# Saved LDA topics with scores for Full Circle Auto Wash (Rating 5)
# Saved LDA topics with scores for Tara R Hodges, DDS (Rating 5)
# Saved LDA topics with scores for LA Fitness (Rating 2)
# Saved LDA topics with scores for LA Fitness (Rating 3)
# Saved LDA topics with scores for LA Fitness (Rating 4)
# Saved LDA topics with scores for LA Fitness (Rating 1)
# Saved LDA topics with scores for LA Fitness (Rating 5)
# Saved LDA topics with scores for Denny's (Rating 3)
# Saved LDA topics with scores for Denny's (Rating 4)
# Saved LDA topics with scores for Denny's (Rating 1)
# Saved LDA topics with scores for Denny's (Rating 2)
# Saved LDA topics with scores for Denny's (Rating 5)
# Saved LDA topics with scores for PetSmart (Rating 4)
# Saved LDA topics with scores for PetSmart (Rating 5)
# Saved LDA topics with scores for PetSmart (Rating 1)
# Saved LDA topics with scores for The Greens Apartments (Rating 5)
# Saved LDA topics with scores for The Greens Apartments (Rating 4)
# Saved LDA topics with scores for The Greens Apartments (Rating 3)
# Saved LDA topics with scores for The Greens Apartments (Rating 1)
# Saved LDA topics with scores for Goodman & Partridge (Rating 1)
# Saved LDA topics with scores for Jiffy Lube (Rating 1)
# Saved LDA topics with scores for Jiffy Lube (Rating 3)
# Saved LDA topics with scores for Jiffy Lube (Rating 5)
# Saved LDA topics with scores for Starbucks (Rating 3)
# Saved LDA topics with scores for Starbucks (Rating 4)
# Saved LDA topics with scores for Starbucks (Rating 5)
# Saved LDA topics with scores for Los Favoritos (Rating 4)
# Saved LDA topics with scores for Los Favoritos (Rating 5)
# Saved LDA topics with scores for Los Favoritos (Rating 3)
# Saved LDA topics with scores for Los Favoritos (Rating 2)
# Saved LDA topics with scores for Los Favoritos (Rating 1)
# Saved LDA topics with scores for Desert Sage Herbs Holistic Center For Body Mind & Spirit (Rating 4)
# Saved LDA topics with scores for Desert Sage Herbs Holistic Center For Body Mind & Spirit (Rating 5)
# Saved LDA topics with scores for Desert Sage Herbs Holistic Center For Body Mind & Spirit (Rating 1)
# Saved LDA topics with scores for Lakeside Apts (Rating 3)
# Saved LDA topics with scores for Lakeside Apts (Rating 2)
# Saved LDA topics with scores for Lakeside Apts (Rating 1)
# Saved LDA topics with scores for Shear Edge (Rating 1)
# Saved LDA topics with scores for Kerry L Taylor, DDS (Rating 2)
# Saved LDA topics with scores for Kerry L Taylor, DDS (Rating 5)
# Saved LDA topics with scores for Kerry L Taylor, DDS (Rating 1)
# Saved LDA topics with scores for Valle Luna Mexican Restaurant (Rating 3)
# Saved LDA topics with scores for Valle Luna Mexican Restaurant (Rating 5)
# Saved LDA topics with scores for Valle Luna Mexican Restaurant (Rating 4)
# Saved LDA topics with scores for Valle Luna Mexican Restaurant (Rating 2)
# Saved LDA topics with scores for Valle Luna Mexican Restaurant (Rating 1)
# Saved LDA topics with scores for Diamondback Cleaners (Rating 1)
# Saved LDA topics with scores for Diamondback Cleaners (Rating 5)
# Saved LDA topics with scores for Diamondback Cleaners (Rating 3)
# Saved LDA topics with scores for Boston Market (Rating 4)
# Saved LDA topics with scores for Boston Market (Rating 3)
# Saved LDA topics with scores for Boston Market (Rating 2)
# Saved LDA topics with scores for Boston Market (Rating 5)
# Saved LDA topics with scores for A New U Day Spa (Rating 4)
# Saved LDA topics with scores for A New U Day Spa (Rating 5)
# Saved LDA topics with scores for A New U Day Spa (Rating 3)
# Saved LDA topics with scores for A New U Day Spa (Rating 1)
# Saved LDA topics with scores for Dogs Day Out (Rating 4)
# Saved LDA topics with scores for Dogs Day Out (Rating 5)
# Saved LDA topics with scores for Dogs Day Out (Rating 1)
# Saved LDA topics with scores for Warner Nails (Rating 5)
# Saved LDA topics with scores for Warner Nails (Rating 4)
# Saved LDA topics with scores for Warner Nails (Rating 3)
# Saved LDA topics with scores for Warner Nails (Rating 2)
# Saved LDA topics with scores for Big Lots (Rating 4)
# Saved LDA topics with scores for Big Lots (Rating 1)
# Saved LDA topics with scores for Big Lots (Rating 2)
# Saved LDA topics with scores for Saigon Pho (Rating 4)
# Saved LDA topics with scores for Saigon Pho (Rating 5)
# Saved LDA topics with scores for Saigon Pho (Rating 2)
# Saved LDA topics with scores for Saigon Pho (Rating 3)
# Saved LDA topics with scores for Saigon Pho (Rating 1)
# Saved LDA topics with scores for Wendy's  (Rating 5)
# Saved LDA topics with scores for Wendy's  (Rating 4)
# Saved LDA topics with scores for Wendy's  (Rating 1)
# Saved LDA topics with scores for Ulta Salon Cosmetics & Fragrance (Rating 2)
# Saved LDA topics with scores for Ulta Salon Cosmetics & Fragrance (Rating 3)
# Saved LDA topics with scores for Ulta Salon Cosmetics & Fragrance (Rating 4)
# Saved LDA topics with scores for Ulta Salon Cosmetics & Fragrance (Rating 1)
# Saved LDA topics with scores for Ulta Salon Cosmetics & Fragrance (Rating 5)
# Saved LDA topics with scores for Ambrosia Floral Boutique (Rating 5)
# Saved LDA topics with scores for Ambrosia Floral Boutique (Rating 1)
# Saved LDA topics with scores for Darling Nails (Rating 4)
# Saved LDA topics with scores for Darling Nails (Rating 1)
# Saved LDA topics with scores for Darling Nails (Rating 5)
# Saved LDA topics with scores for Darling Nails (Rating 3)
# Saved LDA topics with scores for T J Maxx (Rating 3)
# Saved LDA topics with scores for T J Maxx (Rating 2)
# Saved LDA topics with scores for T J Maxx (Rating 4)
# Saved LDA topics with scores for T J Maxx (Rating 5)
# Saved LDA topics with scores for Petco (Rating 4)
# Saved LDA topics with scores for Petco (Rating 1)
# Saved LDA topics with scores for Petco (Rating 5)
# Saved LDA topics with scores for Petco (Rating 2)
# Saved LDA topics with scores for Goodwill of Central Arizona (Rating 5)
# Saved LDA topics with scores for Goodwill of Central Arizona (Rating 3)
# Saved LDA topics with scores for Goodwill of Central Arizona (Rating 4)
# Saved LDA topics with scores for CVS Pharmacy (Rating 5)
# Saved LDA topics with scores for CVS Pharmacy (Rating 2)
# Saved LDA topics with scores for CVS Pharmacy (Rating 3)
# Saved LDA topics with scores for CVS Pharmacy (Rating 4)
# Saved LDA topics with scores for CVS Pharmacy (Rating 1)
# Saved LDA topics with scores for Fitness Forum (Rating 4)
# Saved LDA topics with scores for Fitness Forum (Rating 2)
# Saved LDA topics with scores for Fitness Forum (Rating 1)
# Saved LDA topics with scores for Fitness Forum (Rating 5)
# Saved LDA topics with scores for Fitness Forum (Rating 3)
# Saved LDA topics with scores for Floridino's Pizza & Pasta (Rating 4)
# Saved LDA topics with scores for Floridino's Pizza & Pasta (Rating 5)
# Saved LDA topics with scores for Floridino's Pizza & Pasta (Rating 3)
# Saved LDA topics with scores for Floridino's Pizza & Pasta (Rating 2)
# Saved LDA topics with scores for Floridino's Pizza & Pasta (Rating 1)
# Saved LDA topics with scores for Filiberto's Mexican Food (Rating 2)
# Saved LDA topics with scores for Filiberto's Mexican Food (Rating 5)
# Saved LDA topics with scores for Filiberto's Mexican Food (Rating 1)
# Saved LDA topics with scores for Filiberto's Mexican Food (Rating 4)
# Saved LDA topics with scores for Filiberto's Mexican Food (Rating 3)
# Saved LDA topics with scores for Banfield Pet Hospital (Rating 1)
# Saved LDA topics with scores for Banfield Pet Hospital (Rating 3)
# Saved LDA topics with scores for Banfield Pet Hospital (Rating 2)
# Saved LDA topics with scores for Banfield Pet Hospital (Rating 5)
# Saved LDA topics with scores for Crystal Cleaners (Rating 4)
# Saved LDA topics with scores for Crystal Cleaners (Rating 5)
# Saved LDA topics with scores for Redfish (Rating 4)
# Saved LDA topics with scores for Redfish (Rating 1)
# Saved LDA topics with scores for Redfish (Rating 5)
# Saved LDA topics with scores for 360 Physical Therapy (Rating 2)
# Saved LDA topics with scores for 360 Physical Therapy (Rating 4)
# Saved LDA topics with scores for 360 Physical Therapy (Rating 5)
# Saved LDA topics with scores for Chinese Gourmet Buffet (Rating 4)
# Saved LDA topics with scores for Chinese Gourmet Buffet (Rating 5)
# Saved LDA topics with scores for Chinese Gourmet Buffet (Rating 3)
# Saved LDA topics with scores for Chinese Gourmet Buffet (Rating 1)
# Saved LDA topics with scores for Pesto's Pizza & Wine Bar (Rating 4)
# Saved LDA topics with scores for Pesto's Pizza & Wine Bar (Rating 5)
# Saved LDA topics with scores for Pesto's Pizza & Wine Bar (Rating 1)
# Saved LDA topics with scores for Pesto's Pizza & Wine Bar (Rating 2)
# Saved LDA topics with scores for Pesto's Pizza & Wine Bar (Rating 3)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-587efb48572d> in <cell line: 66>()
#      64
#      65 # Save LDA topics with word scores for each restaurant and each rating
# ---> 66 save_lda_topics_with_scores_by_rating(business_info, output_path='/content/drive/MyDrive/Data Mining Project UIUC/task1/lda_topics_with_scores_output')
#
# <ipython-input-15-587efb48572d> in save_lda_topics_with_scores_by_rating(business_info, output_path)
#      51         for rating, reviews in reviews_by_rating.items():
#      52             if len(reviews) > 0:
# ---> 53                 topics_with_scores = extract_lda_topics_with_scores(reviews)
#      54                 output_file = f"{output_path}/{restaurant_name}_rating_{rating}_lda_topics.json"
#      55                 with open(output_file, 'w') as f:
#
# <ipython-input-15-587efb48572d> in extract_lda_topics_with_scores(reviews, n_topics)
#      31 def extract_lda_topics_with_scores(reviews, n_topics=5):
#      32     vectorizer = CountVectorizer(stop_words='english', max_features=5000)
# ---> 33     X = vectorizer.fit_transform(reviews)
#      34     lda = LatentDirichletAllocation(n_components=n_topics, random_state=0)
#      35     lda.fit(X)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#    1474
#    1475         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1370                     break
#    1371
# -> 1372         vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1373
#    1374         if self.binary:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#    1276             vocabulary = dict(vocabulary)
#    1277             if not vocabulary:
# -> 1278                 raise ValueError(
#    1279                     "empty vocabulary; perhaps the documents only contain stop words"
#    1280                 )
#
# ValueError: empty vocabulary; perhaps the documents only contain stop words

# %% [markdown]
# **Compare the Business**

# %%
# Define the path to your output files
input_path = '/content/drive/MyDrive/Data Mining Project UIUC/task1/lda_topics_with_scores_output'
output_path = '/content/drive/MyDrive/Data Mining Project UIUC/task1/compare_business_viz.json'

# %%
# Select 3 restaurants for visualization
selected_restaurants = [
    "Filiberto's Mexican Food",
    "Carolina's Mexican Food",
    "Elvira's Mexican Food"
]

# Data structure to hold all visualization data
visualization_data = {}

# Iterate through selected restaurants and collect top 5 words for each rating
for restaurant in selected_restaurants:
    restaurant_data = {}
    for rating in range(1, 6):  # Ratings from 1 to 5
        filename = f"{input_path}/{restaurant}_rating_{rating}_lda_topics.json"
        if os.path.exists(filename):
            with open(filename, 'r') as f:
                topics_data = json.load(f)
                top_words_data = []

                # Collect top 5 words for each rating (aggregate across all topics)
                word_scores = {}
                for topic, words_scores in topics_data.items():
                    for word, score in words_scores.items():
                        if word in word_scores:
                            word_scores[word] += score
                        else:
                            word_scores[word] = score

                # Sort and select top 5 words
                top_words = sorted(word_scores.items(), key=lambda x: x[1], reverse=True)[:5]
                top_words_data = [{"word": word, "score": score} for word, score in top_words]

                # Add top words data to rating
                restaurant_data[f"Rating_{rating}"] = top_words_data
        else:
            print(f"File not found: {filename}")
    visualization_data[restaurant] = restaurant_data

# Save the visualization data to a JSON file
with open(output_path, 'w') as f:
    json.dump(visualization_data, f, indent=4)

print(f"Visualization data saved to {output_path}")
# Out:
# Visualization data saved to /content/drive/MyDrive/Data Mining Project UIUC/task1/compare_business_viz.json
